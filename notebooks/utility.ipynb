# %%
import numpy as np
import pandas as pd
import sys

# %%
sectoral_list = pd.read_csv("../data/ind_inftyfinancelist.csv")

# %%
sectoral_list
# Out:
#                                          Company Name            Industry  \
# 0                                      Axis Bank Ltd.  FINANCIAL SERVICES
# 1                                  Bajaj Finance Ltd.  FINANCIAL SERVICES
# 2                                  Bajaj Finserv Ltd.  FINANCIAL SERVICES
# 3                    Bajaj Holdings & Investment Ltd.  FINANCIAL SERVICES
# 4   Cholamandalam Investment and Finance Company Ltd.  FINANCIAL SERVICES
# 5                  HDFC Asset Management Company Ltd.  FINANCIAL SERVICES
# 6                                      HDFC Bank Ltd.  FINANCIAL SERVICES
# 7                    HDFC Life Insurance Company Ltd.  FINANCIAL SERVICES
# 8        Housing Development Finance Corporation Ltd.  FINANCIAL SERVICES
# 9                                     ICICI Bank Ltd.  FINANCIAL SERVICES
# 10       ICICI Lombard General Insurance Company Ltd.  FINANCIAL SERVICES
# 11       ICICI Prudential Life Insurance Company Ltd.  FINANCIAL SERVICES
# ...

# %%
symbol = sectoral_list['Symbol']

# %%
symbol.to_csv("../data/symbol.csv", header = False, index = False)
