# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

from datetime import datetime

# %%
from matplotlib import rc,rcParams

rc('text', usetex=False)
rc('axes', linewidth=2)
rc('font', weight='bold')

# %%
import json
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
file = '../data/data.pkl'
with open(file, 'rb') as handle:
    data_dict = pickle.load(handle)

# %%
data_dict.keys()
# Out:
# dict_keys(['AXISBANK', 'BAJAJFINSV', 'BAJAJHLDNG', 'BAJFINANCE', 'CHOLAFIN', 'HDFC', 'HDFCAMC', 'HDFCBANK', 'HDFCLIFE', 'ICICIBANK', 'ICICIGI', 'ICICIPRULI', 'KOTAKBANK', 'M&MFIN', 'PEL', 'PFC', 'RECLTD', 'SBILIFE', 'SBIN', 'SRTRANSFIN'])

# %%
stocks_under_cosideration = ['AXISBANK', 'BAJFINANCE', 'BAJAJHLDNG', 'CHOLAFIN', 'HDFCBANK', 'ICICIBANK','KOTAKBANK', 'SBIN']

# %%
data_filtered = {}
for stocks in stocks_under_cosideration:
    data_filtered[stocks] = data_dict[stocks]

# %%
data_filtered.keys()
# Out:
# dict_keys(['AXISBANK', 'BAJFINANCE', 'BAJAJHLDNG', 'CHOLAFIN', 'HDFCBANK', 'ICICIBANK', 'KOTAKBANK', 'SBIN'])

# %%
data_filtered['AXISBANK']
# Out:
#         company_name  co_stkdate  nse_opening_price  nse_high_price  \
# 0     AXIS BANK LTD.  31-12-2004             185.00          187.00
# 1     AXIS BANK LTD.  03-01-2005             185.00          191.00
# 2     AXIS BANK LTD.  04-01-2005             191.10          192.00
# 3     AXIS BANK LTD.  05-01-2005             189.95          189.95
# 4     AXIS BANK LTD.  06-01-2005             184.10          190.00
# ...              ...         ...                ...             ...
# 3713  AXIS BANK LTD.  24-12-2019             744.50          744.70
# 3714  AXIS BANK LTD.  26-12-2019             737.50          740.65
# 3715  AXIS BANK LTD.  27-12-2019             739.00          762.00
# 3716  AXIS BANK LTD.  30-12-2019             760.90          765.75
# 3717  AXIS BANK LTD.  31-12-2019             753.85          765.85
#
#       nse_low_price  nse_closing_price  nse_returns  nse_traded_qty  \
# 0            183.00             185.20       1.0100        173505.0
# 1            185.00             190.20       1.0300        284202.0
# 2            187.00             189.70       1.0000        223165.0
# 3            177.55             184.25       0.9700        232617.0
# 4            177.00             185.15       1.0000        238522.0
# ...             ...                ...          ...             ...
# 3713         737.80             740.65       0.9966       3642916.0
# 3714         733.90             736.50       0.9944       7919368.0
# 3715         736.30             760.15       1.0321      10736285.0
# 3716         751.05             754.10       0.9920      10034206.0
# 3717         751.40             754.10       1.0000      11660781.0
#
#       nse_no_of_trans
# 0              1859.0
# 1              2838.0
# 2              1562.0
# 3              2081.0
# 4              2435.0
# ...               ...
# 3713          64957.0
# 3714          71584.0
# 3715         156492.0
# 3716         141431.0
# 3717         131248.0
#
# [3718 rows x 9 columns]

# %%
for key in data_filtered.keys():
    data_filtered[key].reset_index(inplace = True, drop = True)
    data_filtered[key]['co_stkdate'] = pd.to_datetime(data_filtered[key]['co_stkdate'],format='%d-%m-%Y')
    data_filtered[key]['co_stkdate'] = data_filtered[key]['co_stkdate'].dt.strftime('%Y-%m-%d')
    data_filtered[key]['daily_return'] = data_filtered[key]['nse_closing_price'].pct_change()
    data_filtered[key].set_index('co_stkdate', inplace = True)

# %%
data_filtered['AXISBANK']
# Out:
#               company_name  nse_opening_price  nse_high_price  nse_low_price  \
# co_stkdate
# 2004-12-31  AXIS BANK LTD.             185.00          187.00         183.00
# 2005-01-03  AXIS BANK LTD.             185.00          191.00         185.00
# 2005-01-04  AXIS BANK LTD.             191.10          192.00         187.00
# 2005-01-05  AXIS BANK LTD.             189.95          189.95         177.55
# 2005-01-06  AXIS BANK LTD.             184.10          190.00         177.00
# ...                    ...                ...             ...            ...
# 2019-12-24  AXIS BANK LTD.             744.50          744.70         737.80
# 2019-12-26  AXIS BANK LTD.             737.50          740.65         733.90
# 2019-12-27  AXIS BANK LTD.             739.00          762.00         736.30
# 2019-12-30  AXIS BANK LTD.             760.90          765.75         751.05
# 2019-12-31  AXIS BANK LTD.             753.85          765.85         751.40
#
#             nse_closing_price  nse_returns  nse_traded_qty  nse_no_of_trans  \
# co_stkdate
# 2004-12-31             185.20       1.0100        173505.0           1859.0
# 2005-01-03             190.20       1.0300        284202.0           2838.0
# 2005-01-04             189.70       1.0000        223165.0           1562.0
# 2005-01-05             184.25       0.9700        232617.0           2081.0
# 2005-01-06             185.15       1.0000        238522.0           2435.0
# ...                       ...          ...             ...              ...
# 2019-12-24             740.65       0.9966       3642916.0          64957.0
# 2019-12-26             736.50       0.9944       7919368.0          71584.0
# 2019-12-27             760.15       1.0321      10736285.0         156492.0
# 2019-12-30             754.10       0.9920      10034206.0         141431.0
# 2019-12-31             754.10       1.0000      11660781.0         131248.0
#
#             daily_return
# co_stkdate
# 2004-12-31           NaN
# 2005-01-03      0.026998
# 2005-01-04     -0.002629
# 2005-01-05     -0.028730
# 2005-01-06      0.004885
# ...                  ...
# 2019-12-24     -0.003364
# 2019-12-26     -0.005603
# 2019-12-27      0.032111
# 2019-12-30     -0.007959
# 2019-12-31      0.000000
#
# [3718 rows x 9 columns]

# %%
# summary stats
data_filtered['AXISBANK'].describe()
# Out:
#        nse_opening_price  nse_high_price  nse_low_price  nse_closing_price  \
# count        3718.000000     3718.000000    3718.000000        3718.000000
# mean          765.513125      778.322001     751.627905         764.908338
# std           380.766893      385.982298     375.705038         380.848458
# min           176.700000      183.200000     170.000000         175.650000
# 25%           488.437500      495.762500     480.887500         487.950000
# 50%           627.425000      638.500000     616.600000         627.075000
# 75%          1076.412500     1098.987500    1050.775000        1075.787500
# max          2034.400000     2043.050000    2002.600000        2023.350000
#
#        nse_returns  nse_traded_qty  nse_no_of_trans  daily_return
# count  3718.000000    3.718000e+03      3718.000000   3717.000000
# mean      1.001154    4.141529e+06     68352.391877      0.000921
# std       0.025675    5.259973e+06     58839.138477      0.028732
# min       0.850000    2.779900e+04       211.000000     -0.800906
# 25%       0.990000    1.028015e+06     25275.000000     -0.012511
# 50%       1.000000    2.419668e+06     58121.500000      0.000087
# 75%       1.010000    5.869798e+06     97071.750000      0.013971
# max       1.190000    1.205419e+08    770467.000000      0.194263

# %%
# closing price

plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top=14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    data_filtered[company]['nse_closing_price'].plot()
    plt.ylabel('Closing price')
    plt.xlabel(None)
    plt.xticks(rotation = '45')
    plt.title(f"{company}")
plt.show()

# %% [markdown]
# These are the closing prices of our set of selected stocks over the time period ranging from starting of 2005 till the end of 2019.
# We see that there some regions of systemetic sharp decline for all the stocks. We will attemp to answer the causes of these depreciation of stocks values.

# %%
# volume traded
plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top=14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    data_filtered[company]['nse_traded_qty'].plot()
    plt.ylabel('Volume of traded per day')
    plt.xlabel(None)
    plt.xticks(rotation = '45')
    plt.title(f"{company}")
plt.show()
plt.close()

# %% [markdown]
# Some of the drastic increase in net quanity traded per day can be explained due to the phenomenon called 'Share Split' which will be discussed in detail later

# %%
# Moving Averages
ma_day = [10, 20, 50, 100, 150]
for ma in ma_day:
    for company in data_filtered.keys():
        column_name = f"MA for {ma} days"
        data_filtered[company][column_name] = data_filtered[company]['nse_closing_price'].rolling(ma).mean()

plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top=14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    # data_filtered[company]['nse_closing_price'].plot()
    data_filtered[company]['nse_closing_price'].plot(legend = 'nse_closing_price')
    data_filtered[company][ 'MA for 100 days'].plot(legend = 'MA for 100 days')
    data_filtered[company][ 'MA for 150 days'].plot(legend = 'MA for 150 days')
    plt.ylabel('Closing price')
    plt.xlabel(None)
    plt.xticks(rotation = '45', fontsize = 'x-large')
    plt.title(f"{company}")
    plt.legend(loc = 'upper left', fontsize = 'large')
plt.show()

# %% [markdown]
# ### Financial crisis of 2007–2008
# Upon further inspection of the closing prices, we see that the Indian banking sector was affected by the Global Finacial Crisis of 2007-08. From the plots below it is evident that the stock prices begin to tank at the beginning of the year 2008 and keep depreciating till early 2009.
# The first impact of the global crisis on India was felt in the stock market in January 2008. This came through the reversal of inflows from foreign institutional investors (FIIs) into the  country.  India  had  received  about  US  17.7  billion  as  net  equity  investment  nflows  from  FIIs  during  2007.  This  turned  into  a  net  disinvestment  of  US  13.3  billion  during  the period from January 2008 to February 2009. This was the direct result of the massive de-leveraging  of  US  banks  after  the  financial  meltdown.  The  FIIs  withdrew  funds  from  all over the emerging markets for meeting the liquidity requirements of their principals in the US.

# %%
plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top =14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    data_filtered[company]['nse_closing_price'][200:1200].plot()
    plt.ylabel('Closing price')
    plt.xlabel(None)
    plt.axvline(550, color = 'red')
    plt.axvline(850, color = 'red')
    plt.xticks(rotation = '45')
    plt.title(f"{company}")
plt.show()

# %%
start_date = '2007-12-31'
end_date = '2009-03-24'
df_crisis = pd.DataFrame(columns=['company_name', 'closing_price_start_date ' + start_date, 'closing_price_end_date ' + end_date, 'mean_daily_return'])
for i, company in enumerate(data_filtered.keys(), 0):
    #df_crisis['company_name'].loc[i] = company
    df_crisis.loc[i] = [company, data_filtered[company]['nse_closing_price'].loc[start_date],
                        data_filtered[company]['nse_closing_price'].loc[end_date], 
                        data_filtered[company]['nse_returns'].loc[start_date:end_date].mean()]
df_crisis
# Out:
#   company_name  closing_price_start_date 2007-12-31  \
# 0     AXISBANK                               970.45
# 1   BAJFINANCE                               439.20
# 2   BAJAJHLDNG                              2627.90
# 3     CHOLAFIN                               336.05
# 4     HDFCBANK                              1729.10
# 5    ICICIBANK                              1238.70
# 6    KOTAKBANK                              1296.60
# 7         SBIN                              2371.15
#
#    closing_price_end_date 2009-03-24  mean_daily_return
# 0                             371.95           0.997841
# 1                              72.75           0.995216
# 2                             288.90           0.997010
# 3                              26.15           0.992658
# 4                             941.70           0.998671
# 5                             355.45           0.997110
# 6                             268.55           0.996047
# 7                            1032.25           0.998339

# %%
start_date = '2009-03-24'
end_date = '2011-03-24'
df_post_crisis = pd.DataFrame(columns=['company_name', 'closing_price_start_date ' + start_date, 'closing_price_end_date ' + end_date, 'mean_daily_return'])
for i, company in enumerate(data_filtered.keys(), 0):
    df_post_crisis.loc[i] = [company, data_filtered[company]['nse_closing_price'].loc[start_date],
                             data_filtered[company]['nse_closing_price'].loc[end_date],
                             data_filtered[company]['nse_returns'].loc[start_date:end_date].mean()]

df_post_crisis
# Out:
#   company_name  closing_price_start_date 2009-03-24  \
# 0     AXISBANK                               371.95
# 1   BAJFINANCE                                72.75
# 2   BAJAJHLDNG                               288.90
# 3     CHOLAFIN                                26.15
# 4     HDFCBANK                               941.70
# 5    ICICIBANK                               355.45
# 6    KOTAKBANK                               268.55
# 7         SBIN                              1032.25
#
#    closing_price_end_date 2011-03-24  mean_daily_return
# 0                            1319.45           1.002846
# 1                             638.65           1.004940
# 2                             733.90           1.002485
# 3                             176.00           1.004326
# 4                            2192.80           1.001904
# 5                            1053.10           1.002545
# 6                             446.20           1.002605
# 7                            2650.75           1.002064

# %%
start_date = '2005-12-30'
end_date = '2007-12-31'
df_pre_crisis = pd.DataFrame(columns=['company_name', 'closing_price_start_date ' + start_date, 'closing_price_end_date ' + end_date, 'mean_daily_return'])
for i, company in enumerate(data_filtered.keys(), 0):
    #df_crisis['company_name'].loc[i] = company
    df_pre_crisis.loc[i] = [company, data_filtered[company]['nse_closing_price'].loc[start_date],
                            data_filtered[company]['nse_closing_price'].loc[end_date],
                            data_filtered[company]['nse_returns'].loc[start_date:end_date].mean()]
    
df_pre_crisis
# Out:
#   company_name  closing_price_start_date 2005-12-30  \
# 0     AXISBANK                               286.95
# 1   BAJFINANCE                               442.00
# 2   BAJAJHLDNG                              2001.10
# 3     CHOLAFIN                               187.05
# 4     HDFCBANK                               708.75
# 5    ICICIBANK                               585.05
# 6    KOTAKBANK                               223.40
# 7         SBIN                               908.15
#
#    closing_price_end_date 2007-12-31  mean_daily_return
# 0                             970.45            1.00288
# 1                             439.20            1.00054
# 2                            2627.90            1.00086
# 3                             336.05            1.00182
# 4                            1729.10            1.00180
# 5                            1238.70            1.00204
# 6                            1296.60            1.00404
# 7                            2371.15            1.00224

# %%
plt.plot(df_crisis['company_name'], df_crisis['mean_daily_return'], label = 'During Crisis')
plt.title('Mean Daily Returns before, during and after the crisis')
plt.xticks(rotation = '45')
plt.plot(df_pre_crisis['company_name'], df_pre_crisis['mean_daily_return'], label = 'Pre Crisis')
plt.plot(df_post_crisis['company_name'], df_post_crisis['mean_daily_return'], label = 'Post Crisis')
plt.legend(loc = 'best')
plt.axhline(y = 1, color = 'black', linewidth = 0.7)
plt.ylabel('Mean Daily Return')
plt.show()

# %%
df_close_price = pd.DataFrame(columns= data_filtered.keys())
#print(list(df_pre_crisis['closing_price_start_date 2005-12-30']))
df_close_price.loc[0] = list(df_pre_crisis['closing_price_start_date 2005-12-30'])
df_close_price.loc[1] =  list(df_crisis['closing_price_start_date 2007-12-31'])
df_close_price.loc[2] =  list(df_post_crisis['closing_price_start_date 2009-03-24'])
df_close_price.loc[3] = list(df_post_crisis['closing_price_end_date 2011-03-24'])
df_close_price['Date'] = ['2005-12-30', '2007-12-31', '2009-03-24', '2011-03-24']
df_close_price['Date'] = pd.to_datetime(df_close_price['Date']).dt.strftime('%Y-%m-%d')
df_close_price.set_index(df_close_price['Date'], inplace = True)
df_close_price.drop(labels = 'Date', axis = 1, inplace = True)

# %%
df_close_price
# Out:
#             AXISBANK  BAJFINANCE  BAJAJHLDNG  CHOLAFIN  HDFCBANK  ICICIBANK  \
# Date
# 2005-12-30    286.95      442.00      2001.1    187.05    708.75     585.05
# 2007-12-31    970.45      439.20      2627.9    336.05   1729.10    1238.70
# 2009-03-24    371.95       72.75       288.9     26.15    941.70     355.45
# 2011-03-24   1319.45      638.65       733.9    176.00   2192.80    1053.10
#
#             KOTAKBANK     SBIN
# Date
# 2005-12-30     223.40   908.15
# 2007-12-31    1296.60  2371.15
# 2009-03-24     268.55  1032.25
# 2011-03-24     446.20  2650.75

# %%
df_close_price.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Stock Split History of Banks and other Finantial Institutes
#
# From the plots of closing price history of stocks above, we see some dates of sharp decline in the closing prices, e.g. Axis Bank around July 2014, ICICI Bank in December 2014, SBI in November 2014. This is not because to any kind of economic crisis but due to phenomenon called 'Stock Split'.
#
# When a company declares a stock split, the number of shares of that company increases, but the market cap remains the same. Existing shares split, but the underlying value remains the same. As the number of shares increases, price per share goes down.
#
# Stock split is done to infuse liquidity and to make shares affordable for various investors who could not buy the shares of that company before due to high prices.

# %%
#fig, ax = plt.subplots(nrows=1, ncols=2)
#ax[0].plot(data_filtered['AXISBANK']['nse_closing_price'].loc['2014-05-28':'2014-08-30'])

#ax[1].plot(data_filtered['AXISBANK']['nse_traded_qty'].loc['2014-05-28':'2014-08-30'])
#plt.show()

plt.figure(figsize=(24, 6))
plt.suptitle('AXISBANK Stock split July  2014', size = 24)
plt.subplot(1,2,1)
plt.tight_layout()
data_filtered['AXISBANK']['nse_closing_price'].loc['2014-05-28':'2014-08-30'].plot()
plt.ylabel('Closing Price',  size = 18)
plt.xlabel(None)
plt.xticks(rotation = '45')
plt.subplot(1,2,2)
plt.tight_layout()
data_filtered['AXISBANK']['nse_traded_qty'].loc['2014-05-28':'2014-08-30'].plot()
plt.ylabel('Quantity Traded',  size = 18)
plt.xlabel(None)
plt.xticks(rotation = '45')
plt.show()

# %%
plt.figure(figsize=(24, 6))
plt.suptitle('ICICIBANK Stock split December 2014', size = 24)
plt.subplot(1,2,1)
plt.tight_layout()
data_filtered['ICICIBANK']['nse_closing_price'].loc['2014-11-10':'2014-12-30'].plot()
plt.ylabel('Closing Price',  size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)

plt.subplot(1,2,2)
plt.tight_layout()
data_filtered['ICICIBANK']['nse_traded_qty'].loc['2014-11-10':'2014-12-30'].plot()
plt.ylabel('Quantity Traded',  size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)
plt.show()

# %%
plt.figure(figsize=(24, 6))
plt.suptitle('SBIN Stock split November 2014', size = 24)
plt.subplot(1,2,1)
plt.tight_layout()
data_filtered['SBIN']['nse_closing_price'].loc['2014-11-1':'2014-12-10'].plot()
plt.ylabel('Closing Price', size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)
plt.subplot(1,2,2)
plt.tight_layout()
data_filtered['SBIN']['nse_traded_qty'].loc['2014-11-1':'2014-12-10'].plot()
plt.ylabel('Quantity Traded',  size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)
plt.show()

# %%
plt.figure(figsize=(24, 6))
plt.suptitle('BAJFINANCE Stock split August 2016', size = 24)
plt.subplot(1,2,1)
plt.tight_layout()
data_filtered['BAJFINANCE']['nse_closing_price'].loc['2016-08-30':'2016-09-20'].plot()
plt.ylabel('Closing Price', size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)
plt.subplot(1,2,2)
plt.tight_layout()
data_filtered['BAJFINANCE']['nse_traded_qty'].loc['2016-08-30':'2016-09-20'].plot()
plt.ylabel('Quantity Traded',  size = 18)
plt.xticks(rotation = '45')
plt.xlabel(None)
plt.show()

# %% [markdown]
# As expected we see that number of trades increases proportional to the decrease in the stock price, thus keeping the underlying value same and as a result of lower prices more investors are attracted to buy those shares at an affordable price.

# %% [markdown]
# ## Returns Analysis

# %% [markdown]
# Due to stock split we cannot do the analysis of the returns using percentange change in closing prices. We will instead use nse_returns atribute of prowess dx.
#
# The returns are not calculated simply based on the prices of the scrip on the exchange. Returns are calculated to measure all the benefits that accrued to the holder of the scrip by way of change in the market value of the scrip compared to the earlier trading day, dividends earned from the scrip and any gain or loss due to any capital actions of the company.
#
# The returns are expressed as a ratio of the closing price, gains/losses arising due to capital action and dividend per share (if any) to the closing price of previous day. A ratio of more than one indicates a positive return whereas a ratio less than one denotes negative returns.

# %%
plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top=14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    data_filtered[company]['nse_returns'].plot(legend=True, linestyle='--')
    plt.ylabel('Daily Returns')
    plt.xlabel(None)
    plt.xticks(rotation = '45')
    plt.title(f"{company}")
plt.show()

# %%
plt.figure(figsize=(24, 18))
#plt.subplots_adjust(top=14, bottom=13) 
for i, company in enumerate(data_filtered.keys(), 1):
    plt.subplot(4, 2, i)
    plt.tight_layout()
    sns.distplot(data_filtered[company]['nse_returns'].clip(0.9, 1.1), bins = 10, color='purple')
    plt.ylabel('Daily Returns')
    plt.xlabel(None)
    plt.title(f"{company}")
plt.show()

# %% [markdown]
# ## Correlation Between the stocks

# %% [markdown]
# Similarly due to stock split we again use nse_returns atribute of prowess dx

# %%
fin_rets = pd.DataFrame(columns= data_filtered.keys(), index = data_filtered['AXISBANK'].index)
closings_df = pd.DataFrame(columns = data_filtered.keys(), index = data_filtered['AXISBANK'].index)
for key in data_filtered.keys():
    fin_rets[key] = data_filtered[key]['nse_returns']
    closings_df[key] = data_filtered[key]['nse_closing_price']

# %%
sns.pairplot(closings_dfts, kind='reg')

# %%
sns.heatmap(fin_rets.corr(), annot=True, cmap='summer')
# Out:
# <AxesSubplot:>

# %%
rets = fin_rets.dropna()

area = np.pi*20

plt.figure(figsize=(12, 10))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))
